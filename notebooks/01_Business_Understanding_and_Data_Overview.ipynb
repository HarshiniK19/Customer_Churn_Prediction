# %% [markdown]
# ## 01_Business_Understanding & Data Overview
#
# ### Project Objective
# Predict which bank customers are likely to churn in the next 3 months.
#
# ### Business Problem
# Customer churn leads to revenue loss. Early identification allows targeted retention strategies and proactive marketing.
#
# ### Expected Outcome
# - Predict churn probability for each customer
# - Identify high-risk customer segments
# - Provide actionable insights for customer retention

# %%
 ## 1. Import Required Libraries
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Load  dataset
Customer_Churn = pd.read_csv(r"D:\Bank_Churn_Project\data\Customer-Churn-Records.csv")

# %%
# Check first 5 rows
Customer_Churn.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited  Complain  Satisfaction Score Card Type  \
# 0        101348.88       1         1                   2   DIAMOND
# ...

# %%
# dataset info
Customer_Churn.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 18 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   RowNumber           10000 non-null  int64
#  1   CustomerId          10000 non-null  int64
#  2   Surname             10000 non-null  object
#  3   CreditScore         10000 non-null  int64
#  4   Geography           10000 non-null  object
#  5   Gender              10000 non-null  object
#  6   Age                 10000 non-null  int64
#  7   Tenure              10000 non-null  int64
#  8   Balance             10000 non-null  float64
#  9   NumOfProducts       10000 non-null  int64
#  10  HasCrCard           10000 non-null  int64
#  11  IsActiveMember      10000 non-null  int64
#  12  EstimatedSalary     10000 non-null  float64
#  13  Exited              10000 non-null  int64
#  14  Complain            10000 non-null  int64
# ...

# %%
# Check missing values
Customer_Churn.isnull().sum()
# Out:
# RowNumber             0
# CustomerId            0
# Surname               0
# CreditScore           0
# Geography             0
# Gender                0
# Age                   0
# Tenure                0
# Balance               0
# NumOfProducts         0
# HasCrCard             0
# IsActiveMember        0
# EstimatedSalary       0
# Exited                0
# Complain              0
# Satisfaction Score    0
# Card Type             0
# Point Earned          0
# dtype: int64

# %%
# Statistical summary
Customer_Churn.describe()
# Out:
#          RowNumber    CustomerId   CreditScore           Age        Tenure  \
# count  10000.00000  1.000000e+04  10000.000000  10000.000000  10000.000000
# mean    5000.50000  1.569094e+07    650.528800     38.921800      5.012800
# std     2886.89568  7.193619e+04     96.653299     10.487806      2.892174
# min        1.00000  1.556570e+07    350.000000     18.000000      0.000000
# 25%     2500.75000  1.562853e+07    584.000000     32.000000      3.000000
# 50%     5000.50000  1.569074e+07    652.000000     37.000000      5.000000
# 75%     7500.25000  1.575323e+07    718.000000     44.000000      7.000000
# max    10000.00000  1.581569e+07    850.000000     92.000000     10.000000
#
#              Balance  NumOfProducts    HasCrCard  IsActiveMember  \
# count   10000.000000   10000.000000  10000.00000    10000.000000
# mean    76485.889288       1.530200      0.70550        0.515100
# std     62397.405202       0.581654      0.45584        0.499797
# ...

# %%
# Visualize target distribution (Exited)

plt.figure(figsize=(6,4))
sns.countplot(x='Exited', data=Customer_Churn)
plt.title('Churn Distribution (0 = Not Exited, 1 = Exited)')
plt.savefig('../plots/churn_distribution.png')
plt.show()

# %% [markdown]
# ## Initial Observations / Insights
#
# - Dataset has **10,000 rows** and **18 columns**.
# - Features include **numeric** (CreditScore, Age, Balance, EstimatedSalary, etc.) and **categorical** (Gender, Geography, etc.).
# - Target column **Exited** is binary: 0 = Customer stayed, 1 = Customer churned.
# - **Target distribution:** ~20% customers churned, indicating some class imbalance.
# - No missing values in the dataset.
#
# These observations will guide preprocessing, feature engineering, and model building.
